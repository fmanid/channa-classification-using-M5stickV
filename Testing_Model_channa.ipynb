# %% [markdown]
# <a href="https://colab.research.google.com/github/fmanid/channa-classification-using-M5stickV/blob/master/Testing_Model_channa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Single Model .h5 Predictions**
#
# ---

# %%
import numpy as np
from PIL import Image
import tensorflow as tf
import matplotlib.pyplot as plt

# Load the trained model
model = tf.keras.models.load_model('/content/drive/MyDrive/model/model (2).h5')

# Load and preprocess the input image
def preprocess_image(image_path):
    image = Image.open(image_path)
    image = image.resize((224, 224))  # Resize the image to match the model's input shape
    image = image.convert('RGB')  # Convert the image to RGB color mode
    image = np.array(image)  # Convert PIL image to NumPy array
    image = image / 255.0  # Normalize pixel values to the range of 0 and 1
    image = np.expand_dims(image, axis=0)  # Add batch dimension
    return image

# Make predictions
def predict_image(image_path):
    image = preprocess_image(image_path)
    predictions = model.predict(image)
    return predictions

# Path to the input image
image_path = '/content/drive/MyDrive/data testing/andrao/20230226_113816.jpg'

# Make prediction using the input image
predictions = predict_image(image_path)

# Mapping class index to class names
class_names = {
    0: 'andrao',
    1: 'asiatica',
    2: 'auranti',
    3: 'limbata',
    4: 'maru',
    5: 'pulchra',
    6: 'red',
    7: 'stewarti'
}

# Get the predicted class index and confidence
class_index = np.argmax(predictions)
confidence = predictions[0][class_index]

# Print the predicted class label and confidence
predicted_class = class_names[class_index]
print(f"Predicted class: {predicted_class}")
print(f"Confidence: {confidence}")

# Display the input image
image = Image.open(image_path)
plt.imshow(image)
plt.axis('off')

# Add a title showing the predicted class and confidence
plt.title(f"Predicted class: {predicted_class}\nConfidence: {confidence}")
plt.show()
# Out:
# 1/1 [==============================] - 1s 911ms/step
# Predicted class: stewarti
# Confidence: 0.8365280628204346

# %% [markdown]
# ### **Testing model .h5**
#
# ---
#
#
#
# ---
#
#
#
# ---

# %%
import os
import numpy as np
from PIL import Image
import tensorflow as tf
import pandas as pd
from google.colab import drive
from IPython.display import display, HTML

# Mount Google Drive
drive.mount('/content/drive')

# Load the trained model
model = tf.keras.models.load_model('/content/drive/MyDrive/model/model (2).h5')

# Load and preprocess the input image
def preprocess_image(image_path):
    image = Image.open(image_path)
    image = image.resize((224, 224))  # Resize the image to match the model's input shape
    image = image.convert('RGB')  # Convert the image to RGB color mode
    image = np.array(image)  # Convert PIL image to NumPy array
    image = image / 255.0  # Normalize pixel values to the range of 0 and 1
    image = np.expand_dims(image, axis=0)  # Add batch dimension
    return image

# Make predictions
def predict_image(image_path):
    image = preprocess_image(image_path)
    predictions = model.predict(image)
    return predictions

# Path to the folder containing the images in Google Drive
folder_path = '/content/drive/MyDrive/data testing/andrao'

# Initialize a list to store the predicted class labels and confidence scores
predicted_classes = []
confidences = []
image_paths = []

# Iterate over the images in the folder
for filename in os.listdir(folder_path):
    if filename.endswith('.jpg') or filename.endswith('.png'):  # Filter only image files
        image_path = os.path.join(folder_path, filename)
        image_paths.append(image_path)

        # Make prediction using the input image
        predictions = predict_image(image_path)

        # Assuming the model predicts a single class label
        class_index = np.argmax(predictions)
        confidence = predictions[0][class_index]

        # Mapping class index to class names
        class_names = {
            0: 'andrao',
            1: 'asiatica',
            2: 'auranti',
            3: 'limbata',
            4: 'maru',
            5: 'pulchra',
            6: 'red',
            7: 'stewarti'
        }

        # Get the predicted class label
        predicted_class = class_names[class_index]

        # Append the predicted class label and confidence score to the lists
        predicted_classes.append(predicted_class)
        confidences.append(confidence)

# Create a Pandas DataFrame to store the predicted class labels, confidence scores, and image paths
data = {'Predicted Class': predicted_classes, 'Confidence': confidences, 'Image Path': image_paths}
df = pd.DataFrame(data)

# Function to create HTML tag for displaying image in table cell
def image_cell(row):
    image_path = row['Image Path']
    image = Image.open(image_path)
    image.thumbnail((300, 300))
    return f'<img src="data:image/jpeg;base64,{image_to_base64(image)}">'

# Function to convert image to base64
def image_to_base64(image):
    from io import BytesIO
    import base64
    with BytesIO() as buffer:
        image.save(buffer, 'jpeg')
        return base64.b64encode(buffer.getvalue()).decode()

# Convert the image paths to absolute paths
df['Image Path'] = df['Image Path'].apply(lambda path: os.path.abspath(path))

# Convert the image paths to image cells
df['Image'] = df.apply(image_cell, axis=1)

# Set the desired order of columns
column_order = ['Image', 'Predicted Class', 'Confidence', 'Image Path']
df = df[column_order]

# Insert the title "Testing Andrao" above the table
html_content = f'<h2>Testing Andrao</h2>{df.to_html(escape=False)}'

# Display the HTML content
display(HTML(html_content))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 1/1 [==============================] - 0s 493ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# <h2>Testing Andrao</h2><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Image</th>
#       <th>Predicted Class</th>
#       <th>Confidence</th>
#       <th>Image Path</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>pulchra</td>
#       <td>0.730723</td>
#       <td>/content/drive/MyDrive/data testing/andrao/20230226_113842.jpg</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>pulchra</td>
#       <td>0.563385</td>
#       <td>/content/drive/MyDrive/data testing/andrao/20230226_113757.jpg</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>stewarti</td>
#       <td>0.836528</td>
#       <td>/content/drive/MyDrive/data testing/andrao/20230226_113816.jpg</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>andrao</td>
#       <td>0.809572</td>
#       <td>/content/drive/MyDrive/data testing/andrao/20230312_113910.jpg</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>asiatica</td>
#       <td>0.987312</td>
#       <td>/content/drive/MyDrive/data testing/andrao/20230226_115602.jpg</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>andrao</td>
#       <td>0.417667</td>
#       <td>/content/drive/MyDrive/data testing/andrao/20230226_113808.jpg</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>stewarti</td>
#       <td>0.959458</td>
#       <td>/content/drive/MyDrive/data testing/andrao/20230312_113825.jpg</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>pulchra</td>
#       <td>0.445543</td>
#       <td>/content/drive/MyDrive/data testing/andrao/20230226_113810.jpg</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>andrao</td>
#       <td>0.449847</td>
#       <td>/content/drive/MyDrive/data testing/andrao/20230312_113857.jpg</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>asiatica</td>
#       <td>0.460066</td>
#       <td>/content/drive/MyDrive/data testing/andrao/20230312_113822.jpg</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>pulchra</td>
#       <td>0.492871</td>
#       <td>/content/drive/MyDrive/data testing/andrao/20230312_113832.jpg</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>andrao</td>
#       <td>0.580194</td>
#       <td>/content/drive/MyDrive/data testing/andrao/20230226_115611.jpg</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>pulchra</td>
#       <td>0.584243</td>
#       <td>/content/drive/MyDrive/data testing/andrao/20230226_113807.jpg</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>red</td>
#       <td>0.365519</td>
#       <td>/content/drive/MyDrive/data testing/andrao/20230226_113817.jpg</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>andrao</td>
#       <td>0.531808</td>
#       <td>/content/drive/MyDrive/data testing/andrao/20230226_115552.jpg</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>andrao</td>
#       <td>0.352855</td>
#       <td>/content/drive/MyDrive/data testing/andrao/20230226_115550.jpg</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>andrao</td>
#       <td>0.437454</td>
#       <td>/content/drive/MyDrive/data testing/andrao/20230312_113846.jpg</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>asiatica</td>
#       <td>0.434329</td>
#       <td>/content/drive/MyDrive/data testing/andrao/20230312_113904.jpg</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>andrao</td>
#       <td>0.525761</td>
#       <td>/content/drive/MyDrive/data testing/andrao/20230312_113838.jpg</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>pulchra</td>
#       <td>0.389121</td>
#       <td>/content/drive/MyDrive/data testing/andrao/20230312_113851.jpg</td>
#     </tr>
#   </tbody>
# </table>

# %%
import os
import numpy as np
from PIL import Image
import tensorflow as tf
import pandas as pd
from google.colab import drive
from IPython.display import display, HTML

# Mount Google Drive
drive.mount('/content/drive')

# Load the trained model
model = tf.keras.models.load_model('/content/drive/MyDrive/model/model (2).h5')

# Load and preprocess the input image
def preprocess_image(image_path):
    image = Image.open(image_path)
    image = image.resize((224, 224))  # Resize the image to match the model's input shape
    image = image.convert('RGB')  # Convert the image to RGB color mode
    image = np.array(image)  # Convert PIL image to NumPy array
    image = image / 255.0  # Normalize pixel values to the range of 0 and 1
    image = np.expand_dims(image, axis=0)  # Add batch dimension
    return image

# Make predictions
def predict_image(image_path):
    image = preprocess_image(image_path)
    predictions = model.predict(image)
    return predictions

# Path to the folder containing the images in Google Drive
folder_path = '/content/drive/MyDrive/data testing/asiatica'

# Initialize a list to store the predicted class labels and confidence scores
predicted_classes = []
confidences = []
image_paths = []

# Iterate over the images in the folder
for filename in os.listdir(folder_path):
    if filename.endswith('.jpg') or filename.endswith('.png'):  # Filter only image files
        image_path = os.path.join(folder_path, filename)
        image_paths.append(image_path)

        # Make prediction using the input image
        predictions = predict_image(image_path)

        # Assuming the model predicts a single class label
        class_index = np.argmax(predictions)
        confidence = predictions[0][class_index]

        # Mapping class index to class names
        class_names = {
            0: 'andrao',
            1: 'asiatica',
            2: 'auranti',
            3: 'limbata',
            4: 'maru',
            5: 'pulchra',
            6: 'red',
            7: 'stewarti'
        }

        # Get the predicted class label
        predicted_class = class_names[class_index]

        # Append the predicted class label and confidence score to the lists
        predicted_classes.append(predicted_class)
        confidences.append(confidence)

# Create a Pandas DataFrame to store the predicted class labels, confidence scores, and image paths
data = {'Predicted Class': predicted_classes, 'Confidence': confidences, 'Image Path': image_paths}
df = pd.DataFrame(data)

# Function to create HTML tag for displaying image in table cell
def image_cell(row):
    image_path = row['Image Path']
    image = Image.open(image_path)
    image.thumbnail((200, 200))
    return f'<img src="data:image/jpeg;base64,{image_to_base64(image)}">'

# Function to convert image to base64
def image_to_base64(image):
    from io import BytesIO
    import base64
    with BytesIO() as buffer:
        image.save(buffer, 'jpeg')
        return base64.b64encode(buffer.getvalue()).decode()

# Convert the image paths to absolute paths
df['Image Path'] = df['Image Path'].apply(lambda path: os.path.abspath(path))

# Convert the image paths to image cells
df['Image'] = df.apply(image_cell, axis=1)

# Set the desired order of columns
column_order = ['Image', 'Predicted Class', 'Confidence', 'Image Path']
df = df[column_order]

# Insert the title "Testing Asiatica" above the table
html_content = f'<h2>Testing Asiatica</h2>{df.to_html(escape=False)}'

# Display the HTML content
display(HTML(html_content))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 1/1 [==============================] - 0s 340ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 35ms/step
# <h2>Testing Asiatica</h2><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Image</th>
#       <th>Predicted Class</th>
#       <th>Confidence</th>
#       <th>Image Path</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>asiatica</td>
#       <td>0.963022</td>
#       <td>/content/drive/MyDrive/data testing/asiatica/20230226_114924.jpg</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>asiatica</td>
#       <td>0.699481</td>
#       <td>/content/drive/MyDrive/data testing/asiatica/20230226_115108.jpg</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>asiatica</td>
#       <td>0.994217</td>
#       <td>/content/drive/MyDrive/data testing/asiatica/20230226_114929.jpg</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>maru</td>
#       <td>0.531447</td>
#       <td>/content/drive/MyDrive/data testing/asiatica/20230226_114914.jpg</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>asiatica</td>
#       <td>0.989413</td>
#       <td>/content/drive/MyDrive/data testing/asiatica/20230226_115101.jpg</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>asiatica</td>
#       <td>0.957012</td>
#       <td>/content/drive/MyDrive/data testing/asiatica/20230226_115128.jpg</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>asiatica</td>
#       <td>0.991275</td>
#       <td>/content/drive/MyDrive/data testing/asiatica/20230226_115113.jpg</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>maru</td>
#       <td>0.659613</td>
#       <td>/content/drive/MyDrive/data testing/asiatica/20230226_115131.jpg</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>asiatica</td>
#       <td>0.998249</td>
#       <td>/content/drive/MyDrive/data testing/asiatica/20230226_115124.jpg</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>asiatica</td>
#       <td>0.992538</td>
#       <td>/content/drive/MyDrive/data testing/asiatica/20230226_115007.jpg</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>asiatica</td>
#       <td>0.935181</td>
#       <td>/content/drive/MyDrive/data testing/asiatica/20230226_115116.jpg</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>asiatica</td>
#       <td>0.928616</td>
#       <td>/content/drive/MyDrive/data testing/asiatica/20230226_115014.jpg</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>asiatica</td>
#       <td>0.959370</td>
#       <td>/content/drive/MyDrive/data testing/asiatica/20230226_115143.jpg</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>asiatica</td>
#       <td>0.949297</td>
#       <td>/content/drive/MyDrive/data testing/asiatica/20230226_115104.jpg</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>asiatica</td>
#       <td>0.999827</td>
#       <td>/content/drive/MyDrive/data testing/asiatica/IMG_8220.jpg</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>asiatica</td>
#       <td>0.994820</td>
#       <td>/content/drive/MyDrive/data testing/asiatica/IMG_8219.jpg</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>asiatica</td>
#       <td>0.972632</td>
#       <td>/content/drive/MyDrive/data testing/asiatica/IMG_8218.jpg</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>asiatica</td>
#       <td>0.989839</td>
#       <td>/content/drive/MyDrive/data testing/asiatica/IMG_8217.jpg</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>asiatica</td>
#       <td>0.998273</td>
#       <td>/content/drive/MyDrive/data testing/asiatica/13.jpg</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>asiatica</td>
#       <td>0.998169</td>
#       <td>/content/drive/MyDrive/data testing/asiatica/15.jpg</td>
#     </tr>
#   </tbody>
# </table>

# %%
import os
import numpy as np
from PIL import Image
import tensorflow as tf
import pandas as pd
from google.colab import drive
from IPython.display import display, HTML

# Mount Google Drive
drive.mount('/content/drive')

# Load the trained model
model = tf.keras.models.load_model('/content/drive/MyDrive/model/model (2).h5')

# Load and preprocess the input image
def preprocess_image(image_path):
    image = Image.open(image_path)
    image = image.resize((224, 224))  # Resize the image to match the model's input shape
    image = image.convert('RGB')  # Convert the image to RGB color mode
    image = np.array(image)  # Convert PIL image to NumPy array
    image = image / 255.0  # Normalize pixel values to the range of 0 and 1
    image = np.expand_dims(image, axis=0)  # Add batch dimension
    return image

# Make predictions
def predict_image(image_path):
    image = preprocess_image(image_path)
    predictions = model.predict(image)
    return predictions

# Path to the folder containing the images in Google Drive
folder_path = '/content/drive/MyDrive/data testing/auranti'

# Initialize a list to store the predicted class labels and confidence scores
predicted_classes = []
confidences = []
image_paths = []

# Iterate over the images in the folder
for filename in os.listdir(folder_path):
    if filename.endswith('.jpg') or filename.endswith('.png'):  # Filter only image files
        image_path = os.path.join(folder_path, filename)
        image_paths.append(image_path)

        # Make prediction using the input image
        predictions = predict_image(image_path)

        # Assuming the model predicts a single class label
        class_index = np.argmax(predictions)
        confidence = predictions[0][class_index]

        # Mapping class index to class names
        class_names = {
            0: 'andrao',
            1: 'asiatica',
            2: 'auranti',
            3: 'limbata',
            4: 'maru',
            5: 'pulchra',
            6: 'red',
            7: 'stewarti'
        }

        # Get the predicted class label
        predicted_class = class_names[class_index]

        # Append the predicted class label and confidence score to the lists
        predicted_classes.append(predicted_class)
        confidences.append(confidence)

# Create a Pandas DataFrame to store the predicted class labels, confidence scores, and image paths
data = {'Predicted Class': predicted_classes, 'Confidence': confidences, 'Image Path': image_paths}
df = pd.DataFrame(data)

# Function to create HTML tag for displaying image in table cell
def image_cell(row):
    image_path = row['Image Path']
    image = Image.open(image_path)
    image.thumbnail((200, 200))
    return f'<img src="data:image/jpeg;base64,{image_to_base64(image)}">'

# Function to convert image to base64
def image_to_base64(image):
    from io import BytesIO
    import base64
    with BytesIO() as buffer:
        image.save(buffer, 'jpeg')
        return base64.b64encode(buffer.getvalue()).decode()

# Convert the image paths to absolute paths
df['Image Path'] = df['Image Path'].apply(lambda path: os.path.abspath(path))

# Convert the image paths to image cells
df['Image'] = df.apply(image_cell, axis=1)

# Set the desired order of columns
column_order = ['Image', 'Predicted Class', 'Confidence', 'Image Path']
df = df[column_order]

# Insert the title "Testing Auranti" above the table
html_content = f'<h2>Testing Auranti</h2>{df.to_html(escape=False)}'

# Display the HTML content
display(HTML(html_content))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 1/1 [==============================] - 0s 374ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# <h2>Testing Auranti</h2><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Image</th>
#       <th>Predicted Class</th>
#       <th>Confidence</th>
#       <th>Image Path</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>auranti</td>
#       <td>0.999944</td>
#       <td>/content/drive/MyDrive/data testing/auranti/20230226_105225.jpg</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>auranti</td>
#       <td>0.968320</td>
#       <td>/content/drive/MyDrive/data testing/auranti/20230226_105305.jpg</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>auranti</td>
#       <td>0.995729</td>
#       <td>/content/drive/MyDrive/data testing/auranti/20230226_105251.jpg</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>auranti</td>
#       <td>0.786840</td>
#       <td>/content/drive/MyDrive/data testing/auranti/20230226_105104.jpg</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>auranti</td>
#       <td>0.999972</td>
#       <td>/content/drive/MyDrive/data testing/auranti/20230226_105113.jpg</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>auranti</td>
#       <td>0.379738</td>
#       <td>/content/drive/MyDrive/data testing/auranti/20230226_105209.jpg</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>auranti</td>
#       <td>0.995980</td>
#       <td>/content/drive/MyDrive/data testing/auranti/20230226_105459.jpg</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>auranti</td>
#       <td>0.999432</td>
#       <td>/content/drive/MyDrive/data testing/auranti/20230226_105243.jpg</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>auranti</td>
#       <td>0.971948</td>
#       <td>/content/drive/MyDrive/data testing/auranti/20230226_105342.jpg</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>auranti</td>
#       <td>0.912141</td>
#       <td>/content/drive/MyDrive/data testing/auranti/20230226_105322.jpg</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>auranti</td>
#       <td>0.999999</td>
#       <td>/content/drive/MyDrive/data testing/auranti/20230226_105228.jpg</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>auranti</td>
#       <td>0.972354</td>
#       <td>/content/drive/MyDrive/data testing/auranti/20230226_105441.jpg</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>asiatica</td>
#       <td>0.844129</td>
#       <td>/content/drive/MyDrive/data testing/auranti/20230226_105315.jpg</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>auranti</td>
#       <td>0.999993</td>
#       <td>/content/drive/MyDrive/data testing/auranti/20230226_105346.jpg</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>auranti</td>
#       <td>0.999461</td>
#       <td>/content/drive/MyDrive/data testing/auranti/20230226_105253.jpg</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>auranti</td>
#       <td>0.999916</td>
#       <td>/content/drive/MyDrive/data testing/auranti/20230226_105318.jpg</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>auranti</td>
#       <td>0.999492</td>
#       <td>/content/drive/MyDrive/data testing/auranti/20230226_105237.jpg</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>auranti</td>
#       <td>0.999689</td>
#       <td>/content/drive/MyDrive/data testing/auranti/20230226_105325.jpg</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>auranti</td>
#       <td>0.938493</td>
#       <td>/content/drive/MyDrive/data testing/auranti/20230226_105456.jpg</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>auranti</td>
#       <td>0.998966</td>
#       <td>/content/drive/MyDrive/data testing/auranti/20230226_105452.jpg</td>
#     </tr>
#   </tbody>
# </table>

# %%
import os
import numpy as np
from PIL import Image
import tensorflow as tf
import pandas as pd
from google.colab import drive
from IPython.display import display, HTML

# Mount Google Drive
drive.mount('/content/drive')

# Load the trained model
model = tf.keras.models.load_model('/content/drive/MyDrive/model/model (2).h5')

# Load and preprocess the input image
def preprocess_image(image_path):
    image = Image.open(image_path)
    image = image.resize((224, 224))  # Resize the image to match the model's input shape
    image = image.convert('RGB')  # Convert the image to RGB color mode
    image = np.array(image)  # Convert PIL image to NumPy array
    image = image / 255.0  # Normalize pixel values to the range of 0 and 1
    image = np.expand_dims(image, axis=0)  # Add batch dimension
    return image

# Make predictions
def predict_image(image_path):
    image = preprocess_image(image_path)
    predictions = model.predict(image)
    return predictions

# Path to the folder containing the images in Google Drive
folder_path = '/content/drive/MyDrive/data testing/limbata'

# Initialize a list to store the predicted class labels and confidence scores
predicted_classes = []
confidences = []
image_paths = []

# Iterate over the images in the folder
for filename in os.listdir(folder_path):
    if filename.endswith('.jpg') or filename.endswith('.png'):  # Filter only image files
        image_path = os.path.join(folder_path, filename)
        image_paths.append(image_path)

        # Make prediction using the input image
        predictions = predict_image(image_path)

        # Assuming the model predicts a single class label
        class_index = np.argmax(predictions)
        confidence = predictions[0][class_index]

        # Mapping class index to class names
        class_names = {
            0: 'andrao',
            1: 'asiatica',
            2: 'auranti',
            3: 'limbata',
            4: 'maru',
            5: 'pulchra',
            6: 'red',
            7: 'stewarti'
        }

        # Get the predicted class label
        predicted_class = class_names[class_index]

        # Append the predicted class label and confidence score to the lists
        predicted_classes.append(predicted_class)
        confidences.append(confidence)

# Create a Pandas DataFrame to store the predicted class labels, confidence scores, and image paths
data = {'Predicted Class': predicted_classes, 'Confidence': confidences, 'Image Path': image_paths}
df = pd.DataFrame(data)

# Function to create HTML tag for displaying image in table cell
def image_cell(row):
    image_path = row['Image Path']
    image = Image.open(image_path)
    image.thumbnail((200, 200))
    return f'<img src="data:image/jpeg;base64,{image_to_base64(image)}">'

# Function to convert image to base64
def image_to_base64(image):
    from io import BytesIO
    import base64
    with BytesIO() as buffer:
        image.save(buffer, 'jpeg')
        return base64.b64encode(buffer.getvalue()).decode()

# Convert the image paths to absolute paths
df['Image Path'] = df['Image Path'].apply(lambda path: os.path.abspath(path))

# Convert the image paths to image cells
df['Image'] = df.apply(image_cell, axis=1)

# Set the desired order of columns
column_order = ['Image', 'Predicted Class', 'Confidence', 'Image Path']
df = df[column_order]

# Insert the title "Testing Limbata" above the table
html_content = f'<h2>Testing Limbata</h2>{df.to_html(escape=False)}'

# Display the HTML content
display(HTML(html_content))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 1/1 [==============================] - 0s 342ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 32ms/step
# <h2>Testing Limbata</h2><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Image</th>
#       <th>Predicted Class</th>
#       <th>Confidence</th>
#       <th>Image Path</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>stewarti</td>
#       <td>0.598183</td>
#       <td>/content/drive/MyDrive/data testing/limbata/1.jpg</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>asiatica</td>
#       <td>0.297176</td>
#       <td>/content/drive/MyDrive/data testing/limbata/2.jpg</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>pulchra</td>
#       <td>0.562533</td>
#       <td>/content/drive/MyDrive/data testing/limbata/5.jpg</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>red</td>
#       <td>0.404035</td>
#       <td>/content/drive/MyDrive/data testing/limbata/4.jpg</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>andrao</td>
#       <td>0.221758</td>
#       <td>/content/drive/MyDrive/data testing/limbata/11.jpg</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>limbata</td>
#       <td>0.300049</td>
#       <td>/content/drive/MyDrive/data testing/limbata/12.jpg</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>pulchra</td>
#       <td>0.431902</td>
#       <td>/content/drive/MyDrive/data testing/limbata/17.jpg</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>limbata</td>
#       <td>0.694777</td>
#       <td>/content/drive/MyDrive/data testing/limbata/8.jpg</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>maru</td>
#       <td>0.325233</td>
#       <td>/content/drive/MyDrive/data testing/limbata/22.jpg</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>pulchra</td>
#       <td>0.538880</td>
#       <td>/content/drive/MyDrive/data testing/limbata/3.jpg</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>limbata</td>
#       <td>0.834982</td>
#       <td>/content/drive/MyDrive/data testing/limbata/9.jpg</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>maru</td>
#       <td>0.512409</td>
#       <td>/content/drive/MyDrive/data testing/limbata/16.jpg</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>pulchra</td>
#       <td>0.689165</td>
#       <td>/content/drive/MyDrive/data testing/limbata/23.jpg</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>pulchra</td>
#       <td>0.535465</td>
#       <td>/content/drive/MyDrive/data testing/limbata/10.jpg</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>limbata</td>
#       <td>0.477956</td>
#       <td>/content/drive/MyDrive/data testing/limbata/18.jpg</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>pulchra</td>
#       <td>0.639900</td>
#       <td>/content/drive/MyDrive/data testing/limbata/13.jpg</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>pulchra</td>
#       <td>0.556913</td>
#       <td>/content/drive/MyDrive/data testing/limbata/14.jpg</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>pulchra</td>
#       <td>0.320909</td>
#       <td>/content/drive/MyDrive/data testing/limbata/7.jpg</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>pulchra</td>
#       <td>0.382242</td>
#       <td>/content/drive/MyDrive/data testing/limbata/6.jpg</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>maru</td>
#       <td>0.487000</td>
#       <td>/content/drive/MyDrive/data testing/limbata/15.jpg</td>
#     </tr>
#   </tbody>
# </table>

# %%
import os
import numpy as np
from PIL import Image
import tensorflow as tf
import pandas as pd
from google.colab import drive
from IPython.display import display, HTML

# Mount Google Drive
drive.mount('/content/drive')

# Load the trained model
model = tf.keras.models.load_model('/content/drive/MyDrive/model/model (2).h5')

# Load and preprocess the input image
def preprocess_image(image_path):
    image = Image.open(image_path)
    image = image.resize((224, 224))  # Resize the image to match the model's input shape
    image = image.convert('RGB')  # Convert the image to RGB color mode
    image = np.array(image)  # Convert PIL image to NumPy array
    image = image / 255.0  # Normalize pixel values to the range of 0 and 1
    image = np.expand_dims(image, axis=0)  # Add batch dimension
    return image

# Make predictions
def predict_image(image_path):
    image = preprocess_image(image_path)
    predictions = model.predict(image)
    return predictions

# Path to the folder containing the images in Google Drive
folder_path = '/content/drive/MyDrive/data testing/maru'

# Initialize a list to store the predicted class labels and confidence scores
predicted_classes = []
confidences = []
image_paths = []

# Iterate over the images in the folder
for filename in os.listdir(folder_path):
    if filename.endswith('.jpg') or filename.endswith('.png'):  # Filter only image files
        image_path = os.path.join(folder_path, filename)
        image_paths.append(image_path)

        # Make prediction using the input image
        predictions = predict_image(image_path)

        # Assuming the model predicts a single class label
        class_index = np.argmax(predictions)
        confidence = predictions[0][class_index]

        # Mapping class index to class names
        class_names = {
            0: 'andrao',
            1: 'asiatica',
            2: 'auranti',
            3: 'limbata',
            4: 'maru',
            5: 'pulchra',
            6: 'red',
            7: 'stewarti'
        }

        # Get the predicted class label
        predicted_class = class_names[class_index]

        # Append the predicted class label and confidence score to the lists
        predicted_classes.append(predicted_class)
        confidences.append(confidence)

# Create a Pandas DataFrame to store the predicted class labels, confidence scores, and image paths
data = {'Predicted Class': predicted_classes, 'Confidence': confidences, 'Image Path': image_paths}
df = pd.DataFrame(data)

# Function to create HTML tag for displaying image in table cell
def image_cell(row):
    image_path = row['Image Path']
    image = Image.open(image_path)
    image.thumbnail((200, 200))
    return f'<img src="data:image/jpeg;base64,{image_to_base64(image)}">'

# Function to convert image to base64
def image_to_base64(image):
    from io import BytesIO
    import base64
    with BytesIO() as buffer:
        image.save(buffer, 'jpeg')
        return base64.b64encode(buffer.getvalue()).decode()

# Convert the image paths to absolute paths
df['Image Path'] = df['Image Path'].apply(lambda path: os.path.abspath(path))

# Convert the image paths to image cells
df['Image'] = df.apply(image_cell, axis=1)

# Set the desired order of columns
column_order = ['Image', 'Predicted Class', 'Confidence', 'Image Path']
df = df[column_order]

# Insert the title "Testing Maru" above the table
html_content = f'<h2>Testing Maru</h2>{df.to_html(escape=False)}'

# Display the HTML content
display(HTML(html_content))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 1/1 [==============================] - 0s 478ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# <h2>Testing Maru</h2><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Image</th>
#       <th>Predicted Class</th>
#       <th>Confidence</th>
#       <th>Image Path</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>maru</td>
#       <td>0.986351</td>
#       <td>/content/drive/MyDrive/data testing/maru/IMG_20230122_124331.jpg</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>maru</td>
#       <td>0.999574</td>
#       <td>/content/drive/MyDrive/data testing/maru/IMG_20230122_124532.jpg</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>maru</td>
#       <td>0.938172</td>
#       <td>/content/drive/MyDrive/data testing/maru/IMG_20230122_124510.jpg</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>maru</td>
#       <td>0.999634</td>
#       <td>/content/drive/MyDrive/data testing/maru/IMG_20230122_124400.jpg</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>maru</td>
#       <td>0.998638</td>
#       <td>/content/drive/MyDrive/data testing/maru/IMG_20230122_114236.jpg</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>maru</td>
#       <td>0.988786</td>
#       <td>/content/drive/MyDrive/data testing/maru/IMG_20230122_124359.jpg</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>maru</td>
#       <td>0.985117</td>
#       <td>/content/drive/MyDrive/data testing/maru/IMG_20230122_124431.jpg</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>maru</td>
#       <td>0.995786</td>
#       <td>/content/drive/MyDrive/data testing/maru/IMG_20230122_124541.jpg</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>maru</td>
#       <td>0.997549</td>
#       <td>/content/drive/MyDrive/data testing/maru/IMG_20230122_114243.jpg</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>maru</td>
#       <td>0.997736</td>
#       <td>/content/drive/MyDrive/data testing/maru/IMG_20230122_124413.jpg</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>maru</td>
#       <td>0.993161</td>
#       <td>/content/drive/MyDrive/data testing/maru/IMG_20230122_114244.jpg</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>maru</td>
#       <td>0.987922</td>
#       <td>/content/drive/MyDrive/data testing/maru/IMG_20230122_124422.jpg</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>maru</td>
#       <td>0.368594</td>
#       <td>/content/drive/MyDrive/data testing/maru/IMG_20230122_124654.jpg</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>maru</td>
#       <td>0.956085</td>
#       <td>/content/drive/MyDrive/data testing/maru/IMG_20230122_113543.jpg</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>maru</td>
#       <td>0.999531</td>
#       <td>/content/drive/MyDrive/data testing/maru/IMG_20230122_124615.jpg</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>maru</td>
#       <td>0.975985</td>
#       <td>/content/drive/MyDrive/data testing/maru/IMG_20230122_114110.jpg</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>maru</td>
#       <td>0.996467</td>
#       <td>/content/drive/MyDrive/data testing/maru/IMG_20230122_114228.jpg</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>maru</td>
#       <td>0.999946</td>
#       <td>/content/drive/MyDrive/data testing/maru/IMG_20230122_114231.jpg</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>maru</td>
#       <td>0.819267</td>
#       <td>/content/drive/MyDrive/data testing/maru/IMG_20230122_124337.jpg</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>maru</td>
#       <td>0.813860</td>
#       <td>/content/drive/MyDrive/data testing/maru/IMG_20230122_124534.jpg</td>
#     </tr>
#   </tbody>
# </table>

# %%
import os
import numpy as np
from PIL import Image
import tensorflow as tf
import pandas as pd
from google.colab import drive
from IPython.display import display, HTML

# Mount Google Drive
drive.mount('/content/drive')

# Load the trained model
model = tf.keras.models.load_model('/content/drive/MyDrive/model/model (2).h5')

# Load and preprocess the input image
def preprocess_image(image_path):
    image = Image.open(image_path)
    image = image.resize((224, 224))  # Resize the image to match the model's input shape
    image = image.convert('RGB')  # Convert the image to RGB color mode
    image = np.array(image)  # Convert PIL image to NumPy array
    image = image / 255.0  # Normalize pixel values to the range of 0 and 1
    image = np.expand_dims(image, axis=0)  # Add batch dimension
    return image

# Make predictions
def predict_image(image_path):
    image = preprocess_image(image_path)
    predictions = model.predict(image)
    return predictions

# Path to the folder containing the images in Google Drive
folder_path = '/content/drive/MyDrive/data testing/pulchra'

# Initialize a list to store the predicted class labels and confidence scores
predicted_classes = []
confidences = []
image_paths = []

# Iterate over the images in the folder
for filename in os.listdir(folder_path):
    if filename.endswith('.jpg') or filename.endswith('.png'):  # Filter only image files
        image_path = os.path.join(folder_path, filename)
        image_paths.append(image_path)

        # Make prediction using the input image
        predictions = predict_image(image_path)

        # Assuming the model predicts a single class label
        class_index = np.argmax(predictions)
        confidence = predictions[0][class_index]

        # Mapping class index to class names
        class_names = {
            0: 'andrao',
            1: 'asiatica',
            2: 'auranti',
            3: 'limbata',
            4: 'maru',
            5: 'pulchra',
            6: 'red',
            7: 'stewarti'
        }

        # Get the predicted class label
        predicted_class = class_names[class_index]

        # Append the predicted class label and confidence score to the lists
        predicted_classes.append(predicted_class)
        confidences.append(confidence)

# Create a Pandas DataFrame to store the predicted class labels, confidence scores, and image paths
data = {'Predicted Class': predicted_classes, 'Confidence': confidences, 'Image Path': image_paths}
df = pd.DataFrame(data)

# Function to create HTML tag for displaying image in table cell
def image_cell(row):
    image_path = row['Image Path']
    image = Image.open(image_path)
    image.thumbnail((200, 200))
    return f'<img src="data:image/jpeg;base64,{image_to_base64(image)}">'

# Function to convert image to base64
def image_to_base64(image):
    from io import BytesIO
    import base64
    with BytesIO() as buffer:
        image.save(buffer, 'jpeg')
        return base64.b64encode(buffer.getvalue()).decode()

# Convert the image paths to absolute paths
df['Image Path'] = df['Image Path'].apply(lambda path: os.path.abspath(path))

# Convert the image paths to image cells
df['Image'] = df.apply(image_cell, axis=1)

# Set the desired order of columns
column_order = ['Image', 'Predicted Class', 'Confidence', 'Image Path']
df = df[column_order]

# Insert the title "Testing Pulchra" above the table
html_content = f'<h2>Testing Pulchra</h2>{df.to_html(escape=False)}'

# Display the HTML content
display(HTML(html_content))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 1/1 [==============================] - 0s 340ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 33ms/step
# <h2>Testing Pulchra</h2><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Image</th>
#       <th>Predicted Class</th>
#       <th>Confidence</th>
#       <th>Image Path</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>pulchra</td>
#       <td>0.566873</td>
#       <td>/content/drive/MyDrive/data testing/pulchra/IMG_20230122_133154.jpg</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>maru</td>
#       <td>0.456348</td>
#       <td>/content/drive/MyDrive/data testing/pulchra/IMG_20230122_133153.jpg</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>pulchra</td>
#       <td>0.981352</td>
#       <td>/content/drive/MyDrive/data testing/pulchra/IMG_20230122_133129.jpg</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>pulchra</td>
#       <td>0.419449</td>
#       <td>/content/drive/MyDrive/data testing/pulchra/IMG_20230122_133021.jpg</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>pulchra</td>
#       <td>0.907737</td>
#       <td>/content/drive/MyDrive/data testing/pulchra/IMG_20230122_132956.jpg</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>maru</td>
#       <td>0.800459</td>
#       <td>/content/drive/MyDrive/data testing/pulchra/IMG_20230122_113600.jpg</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>pulchra</td>
#       <td>0.729933</td>
#       <td>/content/drive/MyDrive/data testing/pulchra/IMG_20230122_133009.jpg</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>maru</td>
#       <td>0.701537</td>
#       <td>/content/drive/MyDrive/data testing/pulchra/IMG_20230122_124753.jpg</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>maru</td>
#       <td>0.619026</td>
#       <td>/content/drive/MyDrive/data testing/pulchra/IMG_20230122_124707.jpg</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>pulchra</td>
#       <td>0.989770</td>
#       <td>/content/drive/MyDrive/data testing/pulchra/IMG_20230122_124812.jpg</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>pulchra</td>
#       <td>0.591729</td>
#       <td>/content/drive/MyDrive/data testing/pulchra/IMG_20230122_113736.jpg</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>maru</td>
#       <td>0.551665</td>
#       <td>/content/drive/MyDrive/data testing/pulchra/IMG_20230122_133219.jpg</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>maru</td>
#       <td>0.889584</td>
#       <td>/content/drive/MyDrive/data testing/pulchra/IMG_20230122_124845.jpg</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>maru</td>
#       <td>0.569245</td>
#       <td>/content/drive/MyDrive/data testing/pulchra/IMG_20230122_124736.jpg</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>pulchra</td>
#       <td>0.686510</td>
#       <td>/content/drive/MyDrive/data testing/pulchra/IMG_20230122_124740.jpg</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>asiatica</td>
#       <td>0.531260</td>
#       <td>/content/drive/MyDrive/data testing/pulchra/IMG_20230122_133135.jpg</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>pulchra</td>
#       <td>0.833514</td>
#       <td>/content/drive/MyDrive/data testing/pulchra/IMG_20230122_133043.jpg</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>pulchra</td>
#       <td>0.779852</td>
#       <td>/content/drive/MyDrive/data testing/pulchra/IMG_20230122_124820.jpg</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>maru</td>
#       <td>0.760291</td>
#       <td>/content/drive/MyDrive/data testing/pulchra/IMG_20230122_124726.jpg</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>maru</td>
#       <td>0.541898</td>
#       <td>/content/drive/MyDrive/data testing/pulchra/IMG_20230122_124708.jpg</td>
#     </tr>
#   </tbody>
# </table>

# %%
import os
import numpy as np
from PIL import Image
import tensorflow as tf
import pandas as pd
from google.colab import drive
from IPython.display import display, HTML

# Mount Google Drive
drive.mount('/content/drive')

# Load the trained model
model = tf.keras.models.load_model('/content/drive/MyDrive/model/model (2).h5')

# Load and preprocess the input image
def preprocess_image(image_path):
    image = Image.open(image_path)
    image = image.resize((224, 224))  # Resize the image to match the model's input shape
    image = image.convert('RGB')  # Convert the image to RGB color mode
    image = np.array(image)  # Convert PIL image to NumPy array
    image = image / 255.0  # Normalize pixel values to the range of 0 and 1
    image = np.expand_dims(image, axis=0)  # Add batch dimension
    return image

# Make predictions
def predict_image(image_path):
    image = preprocess_image(image_path)
    predictions = model.predict(image)
    return predictions

# Path to the folder containing the images in Google Drive
folder_path = '/content/drive/MyDrive/data testing/red'

# Initialize a list to store the predicted class labels and confidence scores
predicted_classes = []
confidences = []
image_paths = []

# Iterate over the images in the folder
for filename in os.listdir(folder_path):
    if filename.endswith('.jpg') or filename.endswith('.png'):  # Filter only image files
        image_path = os.path.join(folder_path, filename)
        image_paths.append(image_path)

        # Make prediction using the input image
        predictions = predict_image(image_path)

        # Assuming the model predicts a single class label
        class_index = np.argmax(predictions)
        confidence = predictions[0][class_index]

        # Mapping class index to class names
        class_names = {
            0: 'andrao',
            1: 'asiatica',
            2: 'auranti',
            3: 'limbata',
            4: 'maru',
            5: 'pulchra',
            6: 'red',
            7: 'stewarti'
        }

        # Get the predicted class label
        predicted_class = class_names[class_index]

        # Append the predicted class label and confidence score to the lists
        predicted_classes.append(predicted_class)
        confidences.append(confidence)

# Create a Pandas DataFrame to store the predicted class labels, confidence scores, and image paths
data = {'Predicted Class': predicted_classes, 'Confidence': confidences, 'Image Path': image_paths}
df = pd.DataFrame(data)

# Function to create HTML tag for displaying image in table cell
def image_cell(row):
    image_path = row['Image Path']
    image = Image.open(image_path)
    image.thumbnail((200, 200))
    return f'<img src="data:image/jpeg;base64,{image_to_base64(image)}">'

# Function to convert image to base64
def image_to_base64(image):
    from io import BytesIO
    import base64
    with BytesIO() as buffer:
        image.save(buffer, 'jpeg')
        return base64.b64encode(buffer.getvalue()).decode()

# Convert the image paths to absolute paths
df['Image Path'] = df['Image Path'].apply(lambda path: os.path.abspath(path))

# Convert the image paths to image cells
df['Image'] = df.apply(image_cell, axis=1)

# Set the desired order of columns
column_order = ['Image', 'Predicted Class', 'Confidence', 'Image Path']
df = df[column_order]

# Insert the title "Testing Red" above the table
html_content = f'<h2>Testing Red</h2>{df.to_html(escape=False)}'

# Display the HTML content
display(HTML(html_content))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 1/1 [==============================] - 0s 364ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# <h2>Testing Red</h2><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Image</th>
#       <th>Predicted Class</th>
#       <th>Confidence</th>
#       <th>Image Path</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>maru</td>
#       <td>0.694612</td>
#       <td>/content/drive/MyDrive/data testing/red/20230312_113212.jpg</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>red</td>
#       <td>0.756518</td>
#       <td>/content/drive/MyDrive/data testing/red/20230312_113320.jpg</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>red</td>
#       <td>0.552123</td>
#       <td>/content/drive/MyDrive/data testing/red/20230312_113404.jpg</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>red</td>
#       <td>0.538816</td>
#       <td>/content/drive/MyDrive/data testing/red/20230312_113150.jpg</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>maru</td>
#       <td>0.572742</td>
#       <td>/content/drive/MyDrive/data testing/red/20230312_113201.jpg</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>red</td>
#       <td>0.861472</td>
#       <td>/content/drive/MyDrive/data testing/red/20230312_113203.jpg</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>red</td>
#       <td>0.976219</td>
#       <td>/content/drive/MyDrive/data testing/red/20230312_113410.jpg</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>red</td>
#       <td>0.993795</td>
#       <td>/content/drive/MyDrive/data testing/red/20230312_113154.jpg</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>maru</td>
#       <td>0.996085</td>
#       <td>/content/drive/MyDrive/data testing/red/IMG_8189.jpg</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>maru</td>
#       <td>0.945998</td>
#       <td>/content/drive/MyDrive/data testing/red/IMG_8190.jpg</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>red</td>
#       <td>0.959206</td>
#       <td>/content/drive/MyDrive/data testing/red/IMG_8191.jpg</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>red</td>
#       <td>0.906366</td>
#       <td>/content/drive/MyDrive/data testing/red/IMG_8193.jpg</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>red</td>
#       <td>0.957773</td>
#       <td>/content/drive/MyDrive/data testing/red/IMG_8194.jpg</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>red</td>
#       <td>0.675941</td>
#       <td>/content/drive/MyDrive/data testing/red/IMG_8196.jpg</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>red</td>
#       <td>0.990685</td>
#       <td>/content/drive/MyDrive/data testing/red/IMG_8197.jpg</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>maru</td>
#       <td>0.954816</td>
#       <td>/content/drive/MyDrive/data testing/red/IMG_8199.jpg</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>red</td>
#       <td>0.998902</td>
#       <td>/content/drive/MyDrive/data testing/red/IMG_8201.jpg</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>pulchra</td>
#       <td>0.444379</td>
#       <td>/content/drive/MyDrive/data testing/red/IMG_8206.jpg</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>red</td>
#       <td>0.999694</td>
#       <td>/content/drive/MyDrive/data testing/red/IMG_8208.jpg</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>red</td>
#       <td>0.998508</td>
#       <td>/content/drive/MyDrive/data testing/red/IMG_8209.jpg</td>
#     </tr>
#   </tbody>
# </table>

# %%
import os
import numpy as np
from PIL import Image
import tensorflow as tf
import pandas as pd
from google.colab import drive
from IPython.display import display, HTML

# Mount Google Drive
drive.mount('/content/drive')

# Load the trained model
model = tf.keras.models.load_model('/content/drive/MyDrive/model/model (2).h5')

# Load and preprocess the input image
def preprocess_image(image_path):
    image = Image.open(image_path)
    image = image.resize((224, 224))  # Resize the image to match the model's input shape
    image = image.convert('RGB')  # Convert the image to RGB color mode
    image = np.array(image)  # Convert PIL image to NumPy array
    image = image / 255.0  # Normalize pixel values to the range of 0 and 1
    image = np.expand_dims(image, axis=0)  # Add batch dimension
    return image

# Make predictions
def predict_image(image_path):
    image = preprocess_image(image_path)
    predictions = model.predict(image)
    return predictions

# Path to the folder containing the images in Google Drive
folder_path = '/content/drive/MyDrive/data testing/stewarti'

# Initialize a list to store the predicted class labels and confidence scores
predicted_classes = []
confidences = []
image_paths = []

# Iterate over the images in the folder
for filename in os.listdir(folder_path):
    if filename.endswith('.jpg') or filename.endswith('.png'):  # Filter only image files
        image_path = os.path.join(folder_path, filename)
        image_paths.append(image_path)

        # Make prediction using the input image
        predictions = predict_image(image_path)

        # Assuming the model predicts a single class label
        class_index = np.argmax(predictions)
        confidence = predictions[0][class_index]

        # Mapping class index to class names
        class_names = {
            0: 'andrao',
            1: 'asiatica',
            2: 'auranti',
            3: 'limbata',
            4: 'maru',
            5: 'pulchra',
            6: 'red',
            7: 'stewarti'
        }

        # Get the predicted class label
        predicted_class = class_names[class_index]

        # Append the predicted class label and confidence score to the lists
        predicted_classes.append(predicted_class)
        confidences.append(confidence)

# Create a Pandas DataFrame to store the predicted class labels, confidence scores, and image paths
data = {'Predicted Class': predicted_classes, 'Confidence': confidences, 'Image Path': image_paths}
df = pd.DataFrame(data)

# Function to create HTML tag for displaying image in table cell
def image_cell(row):
    image_path = row['Image Path']
    image = Image.open(image_path)
    image.thumbnail((200, 200))
    return f'<img src="data:image/jpeg;base64,{image_to_base64(image)}">'

# Function to convert image to base64
def image_to_base64(image):
    from io import BytesIO
    import base64
    with BytesIO() as buffer:
        image.save(buffer, 'jpeg')
        return base64.b64encode(buffer.getvalue()).decode()

# Convert the image paths to absolute paths
df['Image Path'] = df['Image Path'].apply(lambda path: os.path.abspath(path))

# Convert the image paths to image cells
df['Image'] = df.apply(image_cell, axis=1)

# Set the desired order of columns
column_order = ['Image', 'Predicted Class', 'Confidence', 'Image Path']
df = df[column_order]

# Insert the title "Testing stewarti" above the table
html_content = f'<h2>Testing Stewarti</h2>{df.to_html(escape=False)}'

# Display the HTML content
display(HTML(html_content))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 1/1 [==============================] - 0s 333ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 39ms/step
# <h2>Testing Stewarti</h2><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Image</th>
#       <th>Predicted Class</th>
#       <th>Confidence</th>
#       <th>Image Path</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>pulchra</td>
#       <td>0.374083</td>
#       <td>/content/drive/MyDrive/data testing/stewarti/20230226_111519.jpg</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>stewarti</td>
#       <td>0.854826</td>
#       <td>/content/drive/MyDrive/data testing/stewarti/20230226_111413.jpg</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>stewarti</td>
#       <td>0.657882</td>
#       <td>/content/drive/MyDrive/data testing/stewarti/20230226_111524.jpg</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>auranti</td>
#       <td>0.438358</td>
#       <td>/content/drive/MyDrive/data testing/stewarti/20230226_110707.jpg</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>stewarti</td>
#       <td>0.740652</td>
#       <td>/content/drive/MyDrive/data testing/stewarti/20230226_111514.jpg</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>stewarti</td>
#       <td>0.524922</td>
#       <td>/content/drive/MyDrive/data testing/stewarti/20230226_111528.jpg</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>stewarti</td>
#       <td>0.450748</td>
#       <td>/content/drive/MyDrive/data testing/stewarti/20230226_110651.jpg</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>stewarti</td>
#       <td>0.966113</td>
#       <td>/content/drive/MyDrive/data testing/stewarti/20230226_111453.jpg</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>pulchra</td>
#       <td>0.325170</td>
#       <td>/content/drive/MyDrive/data testing/stewarti/20230226_110813.jpg</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>stewarti</td>
#       <td>0.998284</td>
#       <td>/content/drive/MyDrive/data testing/stewarti/20230226_110624.jpg</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>stewarti</td>
#       <td>0.999470</td>
#       <td>/content/drive/MyDrive/data testing/stewarti/20230226_111429.jpg</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>stewarti</td>
#       <td>0.947846</td>
#       <td>/content/drive/MyDrive/data testing/stewarti/20230226_110631.jpg</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>stewarti</td>
#       <td>0.917806</td>
#       <td>/content/drive/MyDrive/data testing/stewarti/20230226_110814.jpg</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>stewarti</td>
#       <td>0.999940</td>
#       <td>/content/drive/MyDrive/data testing/stewarti/20230226_111508.jpg</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>stewarti</td>
#       <td>0.989688</td>
#       <td>/content/drive/MyDrive/data testing/stewarti/20230226_110633.jpg</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>stewarti</td>
#       <td>0.997512</td>
#       <td>/content/drive/MyDrive/data testing/stewarti/20230226_110722.jpg</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>stewarti</td>
#       <td>0.999985</td>
#       <td>/content/drive/MyDrive/data testing/stewarti/20230226_111405.jpg</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>stewarti</td>
#       <td>0.980250</td>
#       <td>/content/drive/MyDrive/data testing/stewarti/20230226_111418.jpg</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>stewarti</td>
#       <td>0.964788</td>
#       <td>/content/drive/MyDrive/data testing/stewarti/20230226_111502.jpg</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>stewarti</td>
#       <td>0.992068</td>
#       <td>/content/drive/MyDrive/data testing/stewarti/20230226_110709.jpg</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Testing model .tflite dengan data testing**

# %%
import os
import numpy as np
from PIL import Image
import tensorflow as tf
import pandas as pd
from google.colab import drive
from IPython.display import display, HTML

# Mount Google Drive
drive.mount('/content/drive')

# Load the trained model
model_path = '/content/drive/MyDrive/model/model.tflite'
interpreter = tf.lite.Interpreter(model_path=model_path)
interpreter.allocate_tensors()

# Get input and output details
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Load and preprocess the input image
def preprocess_image(image_path):
    image = Image.open(image_path)
    image = image.resize((224, 224))  # Resize the image to match the model's input shape
    image = image.convert('RGB')  # Convert the image to RGB color mode
    image = np.array(image)  # Convert PIL image to NumPy array
    image = image / 255.0  # Normalize pixel values to the range of 0 and 1
    image = np.expand_dims(image, axis=0)  # Add batch dimension
    return image

# Make predictions
def predict_image(image_path):
    image = preprocess_image(image_path)

    # Set input tensor
    input_data = image.astype(np.float32)
    interpreter.set_tensor(input_details[0]['index'], input_data)

    # Run inference
    interpreter.invoke()

    # Get output tensor
    output_data = interpreter.get_tensor(output_details[0]['index'])
    return output_data

# Path to the folder containing the images in Google Drive
folder_path = '/content/drive/MyDrive/data testing/andrao'

# Initialize a list to store the predicted class labels and confidence scores
predicted_classes = []
confidences = []
image_paths = []

# Iterate over the images in the folder
for filename in os.listdir(folder_path):
    if filename.endswith('.jpg') or filename.endswith('.png'):  # Filter only image files
        image_path = os.path.join(folder_path, filename)
        image_paths.append(image_path)

        # Make prediction using the input image
        predictions = predict_image(image_path)

        # Assuming the model predicts a single class label
        class_index = np.argmax(predictions)
        confidence = predictions[0][class_index]

        # Mapping class index to class names
        class_names = {
            0: 'andrao',
            1: 'asiatica',
            2: 'auranti',
            3: 'limbata',
            4: 'maru',
            5: 'pulchra',
            6: 'red',
            7: 'stewarti'
        }

        # Get the predicted class label
        predicted_class = class_names[class_index]

        # Append the predicted class label and confidence score to the lists
        predicted_classes.append(predicted_class)
        confidences.append(confidence)

# Create a Pandas DataFrame to store the predicted class labels, confidence scores, and image paths
data = {'Predicted Class': predicted_classes, 'Confidence': confidences, 'Image Path': image_paths}
df = pd.DataFrame(data)

# Function to create HTML tag for displaying image in table cell
def image_cell(row):
    image_path = row['Image Path']
    image = Image.open(image_path)
    image.thumbnail((200, 200))
    return f'<img src="data:image/jpeg;base64,{image_to_base64(image)}">'

# Function to convert image to base64 format
def image_to_base64(image):
    import io
    import base64
    with io.BytesIO() as buffer:
        image.save(buffer, format='JPEG')
        return base64.b64encode(buffer.getvalue()).decode()

# Convert the image paths to image cells
df['Image'] = df.apply(image_cell, axis=1)

# Set the desired order of columns
column_order = ['Image', 'Predicted Class', 'Confidence', 'Image Path']
df = df[column_order]

# Set the table title
table_title = '<h2>Testing model .tflite Andrao</h2>'

# Display the DataFrame as a table with images and title
display(HTML(table_title + df.to_html(escape=False)))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <h2>Testing model .tflite Andrao</h2><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Image</th>
#       <th>Predicted Class</th>
#       <th>Confidence</th>
#       <th>Image Path</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>pulchra</td>
#       <td>0.730722</td>
#       <td>/content/drive/MyDrive/data testing/andrao/20230226_113842.jpg</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>pulchra</td>
#       <td>0.563388</td>
#       <td>/content/drive/MyDrive/data testing/andrao/20230226_113757.jpg</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>stewarti</td>
#       <td>0.836527</td>
#       <td>/content/drive/MyDrive/data testing/andrao/20230226_113816.jpg</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>andrao</td>
#       <td>0.809572</td>
#       <td>/content/drive/MyDrive/data testing/andrao/20230312_113910.jpg</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>asiatica</td>
#       <td>0.987312</td>
#       <td>/content/drive/MyDrive/data testing/andrao/20230226_115602.jpg</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>andrao</td>
#       <td>0.417670</td>
#       <td>/content/drive/MyDrive/data testing/andrao/20230226_113808.jpg</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>stewarti</td>
#       <td>0.959459</td>
#       <td>/content/drive/MyDrive/data testing/andrao/20230312_113825.jpg</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>pulchra</td>
#       <td>0.445542</td>
#       <td>/content/drive/MyDrive/data testing/andrao/20230226_113810.jpg</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>andrao</td>
#       <td>0.449848</td>
#       <td>/content/drive/MyDrive/data testing/andrao/20230312_113857.jpg</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>asiatica</td>
#       <td>0.460071</td>
#       <td>/content/drive/MyDrive/data testing/andrao/20230312_113822.jpg</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>pulchra</td>
#       <td>0.492875</td>
#       <td>/content/drive/MyDrive/data testing/andrao/20230312_113832.jpg</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>andrao</td>
#       <td>0.580192</td>
#       <td>/content/drive/MyDrive/data testing/andrao/20230226_115611.jpg</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>pulchra</td>
#       <td>0.584242</td>
#       <td>/content/drive/MyDrive/data testing/andrao/20230226_113807.jpg</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>red</td>
#       <td>0.365523</td>
#       <td>/content/drive/MyDrive/data testing/andrao/20230226_113817.jpg</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>andrao</td>
#       <td>0.531807</td>
#       <td>/content/drive/MyDrive/data testing/andrao/20230226_115552.jpg</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>andrao</td>
#       <td>0.352854</td>
#       <td>/content/drive/MyDrive/data testing/andrao/20230226_115550.jpg</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>andrao</td>
#       <td>0.437454</td>
#       <td>/content/drive/MyDrive/data testing/andrao/20230312_113846.jpg</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>asiatica</td>
#       <td>0.434332</td>
#       <td>/content/drive/MyDrive/data testing/andrao/20230312_113904.jpg</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>andrao</td>
#       <td>0.525755</td>
#       <td>/content/drive/MyDrive/data testing/andrao/20230312_113838.jpg</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>pulchra</td>
#       <td>0.389119</td>
#       <td>/content/drive/MyDrive/data testing/andrao/20230312_113851.jpg</td>
#     </tr>
#   </tbody>
# </table>

# %%
import os
import numpy as np
from PIL import Image
import tensorflow as tf
import pandas as pd
from google.colab import drive
from IPython.display import display, HTML

# Mount Google Drive
drive.mount('/content/drive')

# Load the trained model
model_path = '/content/drive/MyDrive/model/model.tflite'
interpreter = tf.lite.Interpreter(model_path=model_path)
interpreter.allocate_tensors()

# Get input and output details
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Load and preprocess the input image
def preprocess_image(image_path):
    image = Image.open(image_path)
    image = image.resize((224, 224))  # Resize the image to match the model's input shape
    image = image.convert('RGB')  # Convert the image to RGB color mode
    image = np.array(image)  # Convert PIL image to NumPy array
    image = image / 255.0  # Normalize pixel values to the range of 0 and 1
    image = np.expand_dims(image, axis=0)  # Add batch dimension
    return image

# Make predictions
def predict_image(image_path):
    image = preprocess_image(image_path)

    # Set input tensor
    input_data = image.astype(np.float32)
    interpreter.set_tensor(input_details[0]['index'], input_data)

    # Run inference
    interpreter.invoke()

    # Get output tensor
    output_data = interpreter.get_tensor(output_details[0]['index'])
    return output_data

# Path to the folder containing the images in Google Drive
folder_path = '/content/drive/MyDrive/data testing/asiatica'

# Initialize a list to store the predicted class labels and confidence scores
predicted_classes = []
confidences = []
image_paths = []

# Iterate over the images in the folder
for filename in os.listdir(folder_path):
    if filename.endswith('.jpg') or filename.endswith('.png'):  # Filter only image files
        image_path = os.path.join(folder_path, filename)
        image_paths.append(image_path)

        # Make prediction using the input image
        predictions = predict_image(image_path)

        # Assuming the model predicts a single class label
        class_index = np.argmax(predictions)
        confidence = predictions[0][class_index]

        # Mapping class index to class names
        class_names = {
            0: 'andrao',
            1: 'asiatica',
            2: 'auranti',
            3: 'limbata',
            4: 'maru',
            5: 'pulchra',
            6: 'red',
            7: 'stewarti'
        }

        # Get the predicted class label
        predicted_class = class_names[class_index]

        # Append the predicted class label and confidence score to the lists
        predicted_classes.append(predicted_class)
        confidences.append(confidence)

# Create a Pandas DataFrame to store the predicted class labels, confidence scores, and image paths
data = {'Predicted Class': predicted_classes, 'Confidence': confidences, 'Image Path': image_paths}
df = pd.DataFrame(data)

# Function to create HTML tag for displaying image in table cell
def image_cell(row):
    image_path = row['Image Path']
    image = Image.open(image_path)
    image.thumbnail((200, 200))
    return f'<img src="data:image/jpeg;base64,{image_to_base64(image)}">'

# Function to convert image to base64 format
def image_to_base64(image):
    import io
    import base64
    with io.BytesIO() as buffer:
        image.save(buffer, format='JPEG')
        return base64.b64encode(buffer.getvalue()).decode()

# Convert the image paths to image cells
df['Image'] = df.apply(image_cell, axis=1)

# Set the desired order of columns
column_order = ['Image', 'Predicted Class', 'Confidence', 'Image Path']
df = df[column_order]

# Set the table title
table_title = '<h2>Testing model .tflite Asiatica</h2>'

# Display the DataFrame as a table with images and title
display(HTML(table_title + df.to_html(escape=False)))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <h2>Testing model .tflite Asiatica</h2><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Image</th>
#       <th>Predicted Class</th>
#       <th>Confidence</th>
#       <th>Image Path</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>asiatica</td>
#       <td>0.963021</td>
#       <td>/content/drive/MyDrive/data testing/asiatica/20230226_114924.jpg</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>asiatica</td>
#       <td>0.699480</td>
#       <td>/content/drive/MyDrive/data testing/asiatica/20230226_115108.jpg</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>asiatica</td>
#       <td>0.994217</td>
#       <td>/content/drive/MyDrive/data testing/asiatica/20230226_114929.jpg</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>maru</td>
#       <td>0.531445</td>
#       <td>/content/drive/MyDrive/data testing/asiatica/20230226_114914.jpg</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>asiatica</td>
#       <td>0.989413</td>
#       <td>/content/drive/MyDrive/data testing/asiatica/20230226_115101.jpg</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>asiatica</td>
#       <td>0.957012</td>
#       <td>/content/drive/MyDrive/data testing/asiatica/20230226_115128.jpg</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>asiatica</td>
#       <td>0.991275</td>
#       <td>/content/drive/MyDrive/data testing/asiatica/20230226_115113.jpg</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>maru</td>
#       <td>0.659613</td>
#       <td>/content/drive/MyDrive/data testing/asiatica/20230226_115131.jpg</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>asiatica</td>
#       <td>0.998249</td>
#       <td>/content/drive/MyDrive/data testing/asiatica/20230226_115124.jpg</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>asiatica</td>
#       <td>0.992538</td>
#       <td>/content/drive/MyDrive/data testing/asiatica/20230226_115007.jpg</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>asiatica</td>
#       <td>0.935179</td>
#       <td>/content/drive/MyDrive/data testing/asiatica/20230226_115116.jpg</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>asiatica</td>
#       <td>0.928616</td>
#       <td>/content/drive/MyDrive/data testing/asiatica/20230226_
td>
#       <td>/content/drive/MyDrive/data testing/red/IMG_8189.jpg</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>maru</td>
#       <td>0.945997</td>
#       <td>/content/drive/MyDrive/data testing/red/IMG_8190.jpg</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>red</td>
#       <td>0.959206</td>
#       <td>/content/drive/MyDrive/data testing/red/IMG_8191.jpg</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>red</td>
#       <td>0.906368</td>
#       <td>/content/drive/MyDrive/data testing/red/IMG_8193.jpg</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>red</td>
#       <td>0.957775</td>
#       <td>/content/drive/MyDrive/data testing/red/IMG_8194.jpg</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>red</td>
#       <td>0.675949</td>
#       <td>/content/drive/MyDrive/data testing/red/IMG_8196.jpg</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>red</td>
#       <td>0.990686</td>
#       <td>/content/drive/MyDrive/data testing/red/IMG_8197.jpg</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>maru</td>
#       <td>0.954816</td>
#       <td>/content/drive/MyDrive/data testing/red/IMG_8199.jpg</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>red</td>
#       <td>0.998902</td>
#       <td>/content/drive/MyDrive/data testing/red/IMG_8201.jpg</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>pulchra</td>
#       <td>0.444374</td>
#       <td>/content/drive/MyDrive/data testing/red/IMG_8206.jpg</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>red</td>
#       <td>0.999694</td>
#       <td>/content/drive/MyDrive/data testing/red/IMG_8208.jpg</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>red</td>
#       <td>0.998508</td>
#       <td>/content/drive/MyDrive/data testing/red/IMG_8209.jpg</td>
#     </tr>
#   </tbody>
# </table>

# %%
import os
import numpy as np
from PIL import Image
import tensorflow as tf
import pandas as pd
from google.colab import drive
from IPython.display import display, HTML

# Mount Google Drive
drive.mount('/content/drive')

# Load the trained model
model_path = '/content/drive/MyDrive/model/model.tflite'
interpreter = tf.lite.Interpreter(model_path=model_path)
interpreter.allocate_tensors()

# Get input and output details
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Load and preprocess the input image
def preprocess_image(image_path):
    image = Image.open(image_path)
    image = image.resize((224, 224))  # Resize the image to match the model's input shape
    image = image.convert('RGB')  # Convert the image to RGB color mode
    image = np.array(image)  # Convert PIL image to NumPy array
    image = image / 255.0  # Normalize pixel values to the range of 0 and 1
    image = np.expand_dims(image, axis=0)  # Add batch dimension
    return image

# Make predictions
def predict_image(image_path):
    image = preprocess_image(image_path)

    # Set input tensor
    input_data = image.astype(np.float32)
    interpreter.set_tensor(input_details[0]['index'], input_data)

    # Run inference
    interpreter.invoke()

    # Get output tensor
    output_data = interpreter.get_tensor(output_details[0]['index'])
    return output_data

# Path to the folder containing the images in Google Drive
folder_path = '/content/drive/MyDrive/data testing/stewarti'

# Initialize a list to store the predicted class labels and confidence scores
predicted_classes = []
confidences = []
image_paths = []

# Iterate over the images in the folder
for filename in os.listdir(folder_path):
    if filename.endswith('.jpg') or filename.endswith('.png'):  # Filter only image files
        image_path = os.path.join(folder_path, filename)
        image_paths.append(image_path)

        # Make prediction using the input image
        predictions = predict_image(image_path)

        # Assuming the model predicts a single class label
        class_index = np.argmax(predictions)
        confidence = predictions[0][class_index]

        # Mapping class index to class names
        class_names = {
            0: 'andrao',
            1: 'asiatica',
            2: 'auranti',
            3: 'limbata',
            4: 'maru',
            5: 'pulchra',
            6: 'red',
            7: 'stewarti'
        }

        # Get the predicted class label
        predicted_class = class_names[class_index]

        # Append the predicted class label and confidence score to the lists
        predicted_classes.append(predicted_class)
        confidences.append(confidence)

# Create a Pandas DataFrame to store the predicted class labels, confidence scores, and image paths
data = {'Predicted Class': predicted_classes, 'Confidence': confidences, 'Image Path': image_paths}
df = pd.DataFrame(data)

# Function to create HTML tag for displaying image in table cell
def image_cell(row):
    image_path = row['Image Path']
    image = Image.open(image_path)
    image.thumbnail((200, 200))
    return f'<img src="data:image/jpeg;base64,{image_to_base64(image)}">'

# Function to convert image to base64 format
def image_to_base64(image):
    import io
    import base64
    with io.BytesIO() as buffer:
        image.save(buffer, format='JPEG')
        return base64.b64encode(buffer.getvalue()).decode()

# Convert the image paths to image cells
df['Image'] = df.apply(image_cell, axis=1)

# Set the desired order of columns
column_order = ['Image', 'Predicted Class', 'Confidence', 'Image Path']
df = df[column_order]

# Set the table title
table_title = '<h2>Testing model .tflite Stewarti</h2>'

# Display the DataFrame as a table with images and title
display(HTML(table_title + df.to_html(escape=False)))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <h2>Testing model .tflite Stewarti</h2><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Image</th>
#       <th>Predicted Class</th>
#       <th>Confidence</th>
#       <th>Image Path</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>pulchra</td>
#       <td>0.374082</td>
#       <td>/content/drive/MyDrive/data testing/stewarti/20230226_111519.jpg</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>stewarti</td>
#       <td>0.854827</td>
#       <td>/content/drive/MyDrive/data testing/stewarti/20230226_111413.jpg</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>stewarti</td>
#       <td>0.657884</td>
#       <td>/content/drive/MyDrive/data testing/stewarti/20230226_111524.jpg</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>auranti</td>
#       <td>0.438349</td>
#       <td>/content/drive/MyDrive/data testing/stewarti/20230226_110707.jpg</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>stewarti</td>
#       <td>0.740650</td>
#       <td>/content/drive/MyDrive/data testing/stewarti/20230226_111514.jpg</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>stewarti</td>
#       <td>0.524913</td>
#       <td>/content/drive/MyDrive/data testing/stewarti/20230226_111528.jpg</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>stewarti</td>
#       <td>0.450734</td>
#       <td>/content/drive/MyDrive/data testing/stewarti/20230226_110651.jpg</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>stewarti</td>
#       <td>0.966112</td>
#       <td>/content/drive/MyDrive/data testing/stewarti/20230226_111453.jpg</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>pulchra</td>
#       <td>0.325170</td>
#       <td>/content/drive/MyDrive/data testing/stewarti/20230226_110813.jpg</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>stewarti</td>
#       <td>0.998284</td>
#       <td>/content/drive/MyDrive/data testing/stewarti/20230226_110624.jpg</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>stewarti</td>
#       <td>0.999470</td>
#       <td>/content/drive/MyDrive/data testing/stewarti/20230226_111429.jpg</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>stewarti</td>
#       <td>0.947846</td>
#       <td>/content/drive/MyDrive/data testing/stewarti/20230226_110631.jpg</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>stewarti</td>
#       <td>0.917803</td>
#       <td>/content/drive/MyDrive/data testing/stewarti/20230226_110814.jpg</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>stewarti</td>
#       <td>0.999940</td>
#       <td>/content/drive/MyDrive/data testing/stewarti/20230226_111508.jpg</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>stewarti</td>
#       <td>0.989688</td>
#       <td>/content/drive/MyDrive/data testing/stewarti/20230226_110633.jpg</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>stewarti</td>
#       <td>0.997512</td>
#       <td>/content/drive/MyDrive/data testing/stewarti/20230226_110722.jpg</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>stewarti</td>
#       <td>0.999985</td>
#       <td>/content/drive/MyDrive/data testing/stewarti/20230226_111405.jpg</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>stewarti</td>
#       <td>0.980250</td>
#       <td>/content/drive/MyDrive/data testing/stewarti/20230226_111418.jpg</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>stewarti</td>
#       <td>0.964788</td>
#       <td>/content/drive/MyDrive/data testing/stewarti/20230226_111502.jpg</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td><img src="data:image/jpeg;base64,..."></td>
#       <td>stewarti</td>
#       <td>0.992068</td>
#       <td>/content/drive/MyDrive/data testing/stewarti/20230226_110709.jpg</td>
#     </tr>
#   </tbody>
# </table>
